# %% [markdown]
# # Data Visualization with Matplotlib and Seaborn
# ### 🎯 What you’ll learn:
#
# * How to create simple charts and plots
#
# * The difference between Matplotlib and Seaborn
#
# * How to visualize trends, comparisons, and distributions

# %% [markdown]
# #### **✅ Step 1: Setup**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('titanic.csv')

# %% [markdown]
# #### **🔹 1. Histogram — Age Distribution**

# %%
plt.hist(df['Age'].dropna(), bins = 20, edgecolor = 'black')
plt.title("Age distribution")
plt.xlabel("Age")
plt.ylabel("count")
plt.show()

# %% [markdown]
# #### **🔹 2. Bar Plot — Survival Count**

# %%
df['Survived'].value_counts().plot(kind = 'bar')
plt.title("Survived Count")
plt.xticks([0,1],['Not Survived','Survived'])
plt.ylabel("Number of passaengers")
plt.show()

# %% [markdown]
# #### **🔹 3. Seaborn: Countplot — Survival by Gender**

# %%
sns.countplot(data = df, x = 'Sex', hue = 'Survived')
plt.title("Survival by Gender")
plt.legend(title = 'Survived', labels = ['NO', 'Yes'])
plt.show()

# %% [markdown]
# #### **🔹 4. Seaborn: Boxplot — Age by Passenger Class**

# %%
sns.boxplot(data = df, x = 'Pclass', y = 'Age')
sns.title("Age distribution by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Age")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 sns.boxplot(data = df, x = 'Pclass', y = 'Age')
# ----> 2 sns.title("Age distribution by Passenger Class")
#       3 plt.xlabel("Passenger Class")
#       4 plt.ylabel("Age")
#
# AttributeError: module 'seaborn' has no attribute 'title'

# %% [markdown]
# #### **🔹 5. Heatmap — Correlation Matrix**
#
# df.corr():
#  Computes the correlation matrix of the DataFrame.
# Correlation measures how strongly two numeric variables are related (ranges from -1 to 1).
#
# * 1 means perfect positive correlation (they increase    together).
#
# * -1 means perfect negative correlation (one increases while the other decreases).
#
# * 0 means no correlation.
#
# sns.heatmap(corr, annot=True, cmap='coolwarm')
#
# * sns.heatmap(...): Plots the correlation matrix as a heatmap — a colored grid.
#
# * corr: The matrix of correlations you just computed.
#
# * annot=True: Writes the actual correlation values (numbers) inside the boxes.
#
# * cmap='coolwarm': A color scheme where:
#
# * Red shades = negative correlation
#
# * Blue shades = positive correlation
#
# * White = around zero

# %%
# Computes the correlation matrix of the DataFrame.
corr = df .corr(numeric_only = True)
sns.heatmap(corr,  annot = True, cmap = 'coolwarm')
plt.title("Correlation matrix")
plt.show()
